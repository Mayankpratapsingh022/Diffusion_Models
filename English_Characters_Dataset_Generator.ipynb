# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nikitricky/dafont")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/nikitricky/dafont?dataset_version_number=1...
# 100%|██████████| 7.23G/7.23G [03:37<00:00, 35.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1

# %% [markdown]
# !pip install -q torchvision matplotlib

# %%
# !pip install -q torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.3 MB/s eta 0:00:00

# %%
import os
import torch
import torchvision.transforms.functional as TF
from PIL import Image, ImageDraw, ImageFont
from multiprocessing import Pool, cpu_count
from tqdm import tqdm

# === CONFIGURATION ===
FONTS_DIR = "/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1"
OUTPUT_DIR = "/content/Sequential_English_Characters_Image_0-9_A-Z"
IMG_SIZE = 128
FONT_SIZE = 100
CHARS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789'
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === SETUP OUTPUT FOLDERS ===
os.makedirs(OUTPUT_DIR, exist_ok=True)
for char in CHARS:
    os.makedirs(os.path.join(OUTPUT_DIR, char), exist_ok=True)

# === FILTER VALID FONTS ===
def is_valid_font(font_path):
    try:
        _ = ImageFont.truetype(font_path, FONT_SIZE)
        return True
    except:
        return False

def get_all_valid_fonts():
    font_paths = []
    for root, _, files in os.walk(FONTS_DIR):
        for f in files:
            if f.lower().endswith(('.ttf', '.otf')):
                path = os.path.join(root, f)
                if is_valid_font(path):
                    font_paths.append(path)
    return font_paths

valid_fonts = get_all_valid_fonts()
print(f"✅ Total Valid Fonts Found: {len(valid_fonts)}")

# === RENDER EACH FONT WITH INDEX ===
def render_font(args):
    index, font_path = args
    try:
        font = ImageFont.truetype(font_path, FONT_SIZE)
        img_name = f"{index+1}.png"  # Start from 1

        for char in CHARS:
            char_folder = os.path.join(OUTPUT_DIR, char)
            save_path = os.path.join(char_folder, img_name)

            if os.path.exists(save_path):
                continue  # Skip if exists

            image = Image.new('L', (IMG_SIZE, IMG_SIZE), color=255)
            draw = ImageDraw.Draw(image)
            bbox = font.getbbox(char)
            w, h = bbox[2] - bbox[0], bbox[3] - bbox[1]
            x = (IMG_SIZE - w) / 2 - bbox[0]
            y = (IMG_SIZE - h) / 2 - bbox[1]
            draw.text((x, y), char, font=font, fill=0)

            tensor = TF.to_tensor(image).to(DEVICE) * 255
            TF.to_pil_image(tensor.byte().squeeze(0)).save(save_path)

    except Exception:
        pass  # Skip bad fonts silently

# === MULTIPROCESSING ===
if __name__ == "__main__":
    font_args = list(enumerate(valid_fonts))  # (index, font_path)
    with Pool(processes=cpu_count()) as pool:
        list(tqdm(pool.imap_unordered(render_font, font_args), total=len(valid_fonts)))
# Out:
# ✅ Total Valid Fonts Found: 143733
# 100%|██████████| 143733/143733 [04:18<00:00, 556.39it/s]

# %%
valid_fonts
# Out:
# ['/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/fontself/Fontself.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/fontself/Fontself.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/fine_todey/FineTodeyDemoRegular.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/fine_todey/FineTodeyDemoInline.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/corporate_suit/corpoaratesdw.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/quickens/QUICKENS.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/quentine_antelope/QuentineAntelope.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/learchitect/LeArchitect.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/woodcutter_summer_shadows/woodcutter Summer Shadows vers2.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/lovemeagain/LoveMeAgain (1).ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/the_black_out/The Black Out.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ghemma/GhemmaPersonalUse.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ghemma/GhemmaPersonalUse.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/betty/Betty Regular.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/crowd_pleaser/Crowd Pleaser DEMO.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/hair_of_the_dog/HAIROFTH.TTF',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/tropical_rothela/TROPICAL ROTHELA.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts
otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/yuminika/Free Yuminika Script.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/nobula/nobula.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/nobula/nobula.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/hexcellent/HEXCELLENT.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/giveny/Giveny Italic.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/giveny/Giveny Italic.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/giveny/Giveny.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/giveny/Giveny.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/magenta_flow/Magenta Flow.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/bouddha_moon/BouddhaMoon.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/flower_4/FlowerFont-Regular.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ryanmagee/Ryanmagee-Regular.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/patatartiner/PATATARTINER.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/offenbacher_reform_cat/Offenbacher Reform CAT.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/regulaire/regulaireDEMO.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/carlosberg/Carlosberg.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/carlosberg/Carlosberg.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/argor_got_scaqh/Arggotsc.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/characters/Characters.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/characters/Characters.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/mountain_8/Mountain.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/behind_violet_eyes/Behind Violet Eyes - TTF.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/behind_violet_eyes/Behind Violet Eyes - OTF.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/sydney_signature/Sydney Signature.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/sydney_signature/Sydney Signature.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/positivewarp/PositiveWarp.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/stay_here/Stay Here.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/acsf_expressive/acsf-expressive-5pt.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/acsf_expressive/acsf-expressive-5pt-light.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase BoldLine.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase MedLine.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase BlackSolid.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase MedSolid.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase RegLine.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase RegSolid.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase BoldSolid.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/middlecase/MidCase BlackLine.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ml_rainbow_kk/ML Rainbow KK v1.2.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/dealyna/Dealyna.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/font_breakdown/font breakdown.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/british_quest/British Quest.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/doomsdaysdragons/DoomsdaysDragons.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/mrs_chocolat/MrsChocolat.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/suchfrosting/SuchFrosting.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/bharatic/Bharatic-Fontw.TTF',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/bharatic/Bharatic-Font.TTF',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/rebelious/REBELIOUS.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/afv/AFV1.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/afv/AFV2.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/degueulasse/degueulasse.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/nihilschiz_handwrit/Nihilschiz Handwriting.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/study_alone/Study Alone.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ohio/Ohio.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ohio/Ohio.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/kbwiggleworm/KBWiggleWorm.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/classico_2/Classico_PersonalUseOnly.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/aikaterine/Aikaterine-free.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/the_rainmaker/The Rainmaker.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/gramophone_nf/GRAMN___.TTF',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/dedaun/dedaun.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/bholu/Bholu Bold.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/bholu/Bholu Bold.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/rachel_lovelyn/Rachel Lovelyn.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/rachel_lovelyn/Rachel Lovelyn.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ventilla_stone/Ventilla Stone.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/cf_metro_parisien/CFMetroParisien-Regular.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM-Inverse.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM-Hollow.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM-Bold.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM-Light.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/futurism2/FUTURISM-Hollow-Inverse.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/generale_script/Generale Script Font.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/generale_script/Generale Script Font.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/jdteresa/jd_teresa.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/seaweed_fire_aoe/SEAWFA__.TTF',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/marriage_2/Marriage.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/mak_ngah_punya/Mak_Ngah_Punya.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/hello_florida/Hello Florida Demo.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/atakana_script_2/Atakana sarif.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/atakana_script_2/Atakana script.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/atakana_script_2/Atakana sarif.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/atakana_script_2/Atakana script.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ridiculous_2/Ridiculous.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/yana/Yana.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/godshinesans/GodshineSans.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/small_memory/SmallMemory.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/the_loccosta/The Loccosta FREE.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/the_loccosta/The Loccosta FREE.otf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcecond.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforceital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcelaser.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforce3dital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforceexpandital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcelaserital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcehalfital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcecondital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforce3d.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcesemital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforceleft.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcegrad.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcesuperital.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforceexpand.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcehalf.ttf',
#  '/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1/fonts/fonts/ranger_force/rangerforcegradital.ttf',
#  ...]

# %%
def get_all_valid_fonts():
    font_paths = []
    for root, _, files in os.walk(FONTS_DIR):
        for f in files:
            if f.lower().endswith(('.ttf', '.otf')):
                path = os.path.join(root, f)
                if is_valid_font(path):
                    font_paths.append(path)
    return font_paths

valid_fonts = get_all_valid_fonts()
print(f"✅ Total Valid Fonts Found: {len(valid_fonts)}")

# %%
import os
import torch
import torchvision.transforms.functional as TF
from PIL import Image, ImageDraw, ImageFont
from multiprocessing import Pool, cpu_count
from tqdm import tqdm
import random

# === CONFIGURATION ===
FONTS_DIR = "/root/.cache/kagglehub/datasets/nikitricky/dafont/versions/1"
OUTPUT_DIR = "/content/UniqueName_English_Characters_Image_0-9_A-Z"
IMG_SIZE = 128
FONT_SIZE = 100
CHARS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789'
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === SETUP OUTPUT FOLDERS ===
os.makedirs(OUTPUT_DIR, exist_ok=True)
for char in CHARS:
    os.makedirs(os.path.join(OUTPUT_DIR, char), exist_ok=True)

# === FILTER VALID FONTS ===
def is_valid_font(font_path):
    try:
        _ = ImageFont.truetype(font_path, FONT_SIZE)
        return True
    except:
        return False

# === RENDER EACH FONT ===
def render_font(font_path):
    try:
        font_name = os.path.splitext(os.path.basename(font_path))[0].replace(" ", "_").replace("/", "_")
        font = ImageFont.truetype(font_path, FONT_SIZE)

        for char in CHARS:
            char_folder = os.path.join(OUTPUT_DIR, char)
            rand_id = random.randint(100000, 999999)
            image_name = f"{font_name}_{char}_{rand_id}.png"
            save_path = os.path.join(char_folder, image_name)

            if os.path.exists(save_path):
                continue  # Avoid duplicates

            image = Image.new('L', (IMG_SIZE, IMG_SIZE), color=255)
            draw = ImageDraw.Draw(image)
            bbox = font.getbbox(char)
            w, h = bbox[2] - bbox[0], bbox[3] - bbox[1]
            x = (IMG_SIZE - w) / 2 - bbox[0]
            y = (IMG_SIZE - h) / 2 - bbox[1]
            draw.text((x, y), char, font=font, fill=0)

            tensor = TF.to_tensor(image).to(DEVICE) * 255
            TF.to_pil_image(tensor.byte().squeeze(0)).save(save_path)

    except Exception:
        pass  # Skip broken fonts silently

# === MULTIPROCESSING ===
if __name__ == "__main__":
    with Pool(processes=cpu_count()) as pool:
        list(tqdm(pool.imap_unordered(render_font, valid_fonts), total=len(valid_fonts)))
# Out:
#  77%|███████▋  | 110140/143733 [03:14<00:55, 606.93it/s]

# %%
import os

folder_path = "/content/UniqueName_English_Characters_Image_0-9_A-Z/0"
file_count = len([f for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg', '.webp'))])

print(f"Total images in '0': {file_count}")

# %%
import os

folder_path = "/content/Sequential_English_Characters_Image_0-9_A-Z/0"
file_count = len([f for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg', '.webp'))])

print(f"Total images in '0': {file_count}")
